# %% [markdown]
# # Laboratorium 1 - analiza koszykowa
#
# ## Przygotowanie
#
#  * pobierz i wypakuj dataset: https://kaggle.com/datasets/rashikrahmanpritom/groceries-dataset-for-market-basket-analysismba?resource=download&select=basket.csv
#    * alternatywnie, pobierz plik `basket.csv` z Teamsów
#  * [opcjonalnie] Utwórz wirtualne środowisko
#  `python3 -m venv ./recsyslab1`
#  * zainstaluj potrzebne biblioteki:
#  `pip install more-itertools`

# %% [markdown]
# ## Część 1. - przygotowanie danych

# %%
# importujemy wszystkie potrzebne pakiety

from more_itertools import powerset

# %%
# definiujemy stale

PATH = './basket.csv'
EPSILON = 0.001
K = 4

# %%
# wczytujemy dane o koszykach

def read_baskets(path: str) -> list[tuple[str]]:
    with open(path) as f:
        raw = f.read()
    baskets = [set([y.lower() for y in x.split(',') if y]) for x in raw.split('\n')[1:] if x]
    return baskets

def unique_products(baskets: list[tuple[str]]) -> list[str]:
    products = set()
    for basket in baskets:
        products.update(basket)
    return sorted(list(products))

baskets = read_baskets(PATH)
products = unique_products(baskets)
baskets[:10]
# Out:
# [{'pastry', 'salty snack', 'whole milk'},
#  {'sausage', 'semi-finished bread', 'whole milk', 'yogurt'},
#  {'pickled vegetables', 'soda'},
#  {'canned beer', 'misc. beverages'},
#  {'hygiene articles', 'sausage'},
#  {'rolls/buns', 'sausage', 'whole milk'},
#  {'soda', 'whole milk'},
#  {'frankfurter', 'soda', 'whipped/sour cream'},
#  {'curd', 'frankfurter'},
#  {'beef', 'white bread'}]

# %% [markdown]
# ## Część 2. - obliczanie wskaźników

# %%
# obliczamy strukture danych (np. slownik albo graf) przechowujaca wszystkie interesujace wartosci `support`

def get_supports(baskets: list[tuple[str]], all_products: list[str], epsilon: float):
    all_products = sorted(all_products)
    baskets = [set(basket) for basket in baskets]
    total_baskets = len(baskets)
    def find_supports_rec(selected_items: set[str], remaining_baskets: list[set[str]], index: int):
        if len(selected_items) == K+1:
            return dict()

        if index == len(all_products):
            return dict()

        current_item = all_products[index]
        supports = find_supports_rec(selected_items, remaining_baskets, index + 1)
        selected_items.add(current_item)
        filtered_baskets = [basket for basket in remaining_baskets if current_item in basket]
        # current_item in basket is equivalent to basket.issuperset(selected_items) because all baskets in remaining_baskets
        # must contain all items in taken except the current item due to construction
        supp = len(filtered_baskets) / total_baskets
        if supp > epsilon:
            supports[frozenset(selected_items)] = supp
            supports.update(find_supports_rec(selected_items, filtered_baskets, index + 1))
        selected_items.remove(current_item)
        return supports
    return find_supports_rec(set(), baskets, 0)


supports = get_supports(baskets, products, EPSILON)
print(len(supports))
supports
# Out:
# 750
# {frozenset({'zwieback'}): 0.004009891064626078,
#  frozenset({'yogurt'}): 0.08587850030074183,
#  frozenset({'whole milk'}): 0.15792287642852368,
#  frozenset({'whole milk', 'yogurt'}): 0.011160863463209249,
#  frozenset({'white wine'}): 0.011695515605159393,
#  frozenset({'white wine', 'whole milk'}): 0.0012697988371315912,
#  frozenset({'white bread'}): 0.023992514870012697,
#  frozenset({'white bread', 'yogurt'}): 0.0010693042839002875,
#  frozenset({'white bread', 'whole milk'}): 0.003141081333957094,
#  frozenset({'whipped/sour cream'}): 0.043707812604424245,
#  frozenset({'soda', 'specialty chocolate'}): 0.001403461872619127,
#  frozenset({'soda', 'specialty bar'}): 0.0012697988371315912,
#  frozenset({'soap'}): 0.0013366303548753592,
#  frozenset({'snack products'}): 0.001804450979081735,
#  frozenset({'sliced cheese'}): 0.014034618726191272,
#  frozenset({'sliced cheese', 'whole milk'}): 0.0014702933903628951,
#  frozenset({'sliced cheese', 'soda'}): 0.0011361358016440553,
#  frozenset({'skin care'}): 0.0013366303548753592,
#  frozenset({'shopping bags'}): 0.04758404063356279,
#  frozenset({'shopping bags', 'yogurt'}): 0.003542070440419702,
#  frozenset({'shopping bags', 'whole milk'}): 0.006348994185657956,
#  frozenset({'shopping bags', 'whipped/sour cream'}): 0.0012029673193878234,
#  frozenset({'shopping bags', 'tropical fruit'}): 0.0027400922274944863,
#  frozenset({'shopping bags', 'soda'}): 0.004410880171088686,
#  frozenset({'semi-finished bread'}): 0.009490075519615051,
#  frozenset({'semi-finished bread', 'whole milk'}): 0.001670787943594199,
#  frozenset({'seasonal products'}): 0.007084140880839404,
#  frozenset({'sausage'}): 0.06034886052262247,
#  frozenset({'sausage', 'yogurt'}): 0.005747510525964045,
#  frozenset({'sausage', 'whole milk'}): 0.008955423377664907,
#  frozenset({'sausage', 'whole milk', 'yogurt'}): 0.0014702933903628951,
#  frozenset({'sausage', 'white bread'}): 0.001403461872619127,
#  frozenset({'sausage', 'whipped/sour cream'}): 0.002138608567800575,
#  frozenset({'sausage', 'uht-milk'}): 0.0011361358016440553,
#  frozenset({'sausage', 'tropical fruit'}): 0.0030742498162133263,
#  frozenset({'sausage', 'soda'}): 0.005948005079195348,
#  frozenset({'sausage', 'soda', 'whole milk'}): 0.0010693042839002875,
#  frozenset({'sausage', 'sliced cheese'}): 0.0011361358016440553,
#  frozenset({'sausage', 'shopping bags'}): 0.0019381140145692708,
#  frozenset({'sauces'}): 0.0029405867807257902,
#  frozenset({'salty snack'}): 0.018779656485998796,
#  frozenset({'salty snack', 'yogurt'}): 0.0015371249081066632,
#  frozenset({'salty snack', 'whole milk'}): 0.0019381140145692708,
#  frozenset({'salty snack', 'tropical fruit'}): 0.0010024727661565194,
#  frozenset({'salty snack', 'soda'}): 0.001403461872619127,
#  frozenset({'salty snack', 'sausage'}): 0.0011361358016440553,
#  frozenset({'salt'}): 0.005948005079195348,
#  frozenset({'rum'}): 0.002138608567800575,
#  frozenset({'root vegetables'}): 0.06957160997126245,
#  frozenset({'root vegetables', 'yogurt'}): 0.00427721713560115,
#  frozenset({'root vegetables', 'whole milk'}): 0.00755196150504578,
#  frozenset({'root vegetables', 'white bread'}): 0.0012697988371315912,
#  frozenset({'root vegetables', 'whipped/sour cream'}): 0.0024727661565194146,
#  frozenset({'root vegetables', 'waffles'}): 0.0013366303548753592,
#  frozenset({'root vegetables', 'uht-milk'}): 0.0010024727661565194,
#  frozenset({'root vegetables', 'tropical fruit'}): 0.0036757334759072377,
#  frozenset({'root vegetables', 'soda'}): 0.005279689901757669,
#  frozenset({'root vegetables', 'sliced cheese'}): 0.0012029673193878234,
#  frozenset({'popcorn'}): 0.003207912851700862,
#  frozenset({'pip fruit'}): 0.049054334023925686,
#  frozenset({'pip fruit', 'yogurt'}): 0.00360890195816347,
#  frozenset({'pip fruit', 'whole milk'}): 0.006616320256633028,
#  frozenset({'pip fruit', 'whipped/sour cream'}): 0.001670787943594199,
#  frozenset({'pip fruit', 'tropical fruit'}): 0.0020717770500568067,
#  frozenset({'pip fruit', 'soda'}): 0.00394305954688231,
#  frozenset({'pip fruit', 'shopping bags'}): 0.001871282496825503,
#  frozenset({'pip fruit', 'sausage'}): 0.002138608567800575,
#  frozenset({'pip fruit', 'root vegetables'}): 0.0026732607097507185,
#  frozenset({'pip fruit', 'rolls/buns'}): 0.004945532313038829,
#  frozenset({'pip fruit', 'pork'}): 0.001603956425850431,
#  frozenset({'pickled vegetables'}): 0.008955423377664907,
#  frozenset({'pickled vegetables', 'whole milk'}): 0.0010024727661565194,
#  frozenset({'photo/film'}): 0.005279689901757669,
#  frozenset({'pet care'}): 0.005680679008220277,
#  frozenset({'pastry'}): 0.0517275947336764,
#  frozenset({'pastry', 'yogurt'}): 0.00360890195816347,
#  frozenset({'pastry', 'whole milk'}): 0.006482657221145492,
#  frozenset({'pastry', 'whipped/sour cream'}): 0.0015371249081066632,
#  frozenset({'pastry', 'tropical fruit'}): 0.002806923745238254,
#  frozenset({'pastry', 'soda'}): 0.0040767225823698456,
#  frozenset({'pastry', 'shopping bags'}): 0.0013366303548753592,
#  frozenset({'pastry', 'sausage'}): 0.003207912851700862,
#  frozenset({'pastry', 'root vegetables'}): 0.0028737552629820224,
#  frozenset({'pastry', 'rolls/buns'}): 0.00394305954688231,
#  frozenset({'pastry', 'pork'}): 0.0015371249081066632,
#  frozenset({'pastry', 'pip fruit'}): 0.002205440085544343,
#  frozenset({'pasta'}): 0.008086613646995923,
#  frozenset({'pasta', 'whole milk'}): 0.0010693042839002875,
#  frozenset({'packaged fruit/vegetables'}): 0.00848760275345853,
#  frozenset({'packaged fruit/vegetables', 'rolls/buns'}): 0.0012029673193878234,
#  frozenset({'other vegetables'}): 0.12210118291786407,
#  frozenset({'other vegetables', 'yogurt'}): 0.008086613646995923,
#  frozenset({'other vegetables', 'whole milk'}): 0.014836596939116486,
#  frozenset({'other vegetables',
#             'whole milk',
#             'yogurt'}): 0.0011361358016440553,
#  frozenset({'other vegetables', 'white bread'}): 0.0026064291920069507,
#  frozenset({'other vegetables', 'whipped/sour cream'}): 0.004143554100113613,
#  frozenset({'other vegetables', 'waffles'}): 0.0017376194613379669,
#  frozenset({'other vegetables', 'uht-milk'}): 0.002138608567800575,
#  frozenset({'other vegetables', 'tropical fruit'}): 0.006282162667914188,
#  frozenset({'other vegetables', 'sugar'}): 0.0012697988371315912,
#  frozenset({'other vegetables', 'specialty chocolate'}): 0.001670787943594199,
#  frozenset({'other vegetables', 'specialty bar'}): 0.001670787943594199,
#  frozenset({'other vegetables', 'soft cheese'}): 0.0012029673193878234,
#  frozenset({'other vegetables', 'soda'}): 0.009690570072846355,
#  frozenset({'other vegetables', 'soda', 'whole milk'}): 0.0011361358016440553,
#  frozenset({'other vegetables', 'sliced cheese'}): 0.001403461872619127,
#  frozenset({'other vegetables', 'shopping bags'}): 0.004945532313038829,
#  frozenset({'other vegetables', 'semi-finished bread'}): 0.0010024727661565194,
#  frozenset({'other vegetables', 'sausage'}): 0.006014836596939116,
#  frozenset({'other vegetables', 'salty snack'}): 0.002205440085544343,
#  frozenset({'other vegetables', 'root vegetables'}): 0.005279689901757669,
#  frozenset({'other vegetables', 'rolls/buns'}): 0.010559379803515338,
#  frozenset({'other vegetables',
#             'rolls/buns',
#             'whole milk'}): 0.0012029673193878234,
#  frozenset({'other vegetables', 'rolls/buns', 'soda'}): 0.0011361358016440553,
#  frozenset({'other vegetables', 'red/blush wine'}): 0.0011361358016440553,
#  frozenset({'other vegetables', 'pot plants'}): 0.0010024727661565194,
#  frozenset({'other vegetables', 'pork'}): 0.00394305954688231,
#  frozenset({'other vegetables', 'pip fruit'}): 0.004945532313038829,
#  frozenset({'other vegetables', 'pastry'}): 0.0036757334759072377,
#  frozenset({'organic sausage'}): 0.0014702933903628951,
#  frozenset({'onions'}): 0.02024994987636169,
#  frozenset({'onions', 'yogurt'}): 0.0012697988371315912,
#  frozenset({'onions', 'whole milk'}): 0.0029405867807257902,
#  frozenset({'onions', 'whipped/sour cream'}): 0.0010693042839002875,
#  frozenset({'onions', 'tropical fruit'}): 0.0012029673193878234,
#  frozenset({'onions', 'soda'}): 0.0014702933903628951,
#  frozenset({'onions', 'root vegetables'}): 0.0013366303548753592,
#  frozenset({'onions', 'rolls/buns'}): 0.0017376194613379669,
#  frozenset({'onions', 'other vegetables'}): 0.0015371249081066632,
#  frozenset({'oil'}): 0.014903428456860256,
#  frozenset({'oil', 'yogurt'}): 0.0010693042839002875,
#  frozenset({'oil', 'whole milk'}): 0.0019381140145692708,
#  frozenset({'oil', 'soda'}): 0.001804450979081735,
#  frozenset({'oil', 'rolls/buns'}): 0.0013366303548753592,
#  frozenset({'oil', 'other vegetables'}): 0.001804450979081735,
#  frozenset({'nuts/prunes'}): 0.002205440085544343,
#  frozenset({'nut snack'}): 0.0014702933903628951,
#  frozenset({'newspapers'}): 0.038895943326872955,
#  frozenset({'newspapers', 'yogurt'}): 0.0028737552629820224,
#  frozenset({'newspapers', 'whole milk'}): 0.005613847490476508,
#  frozenset({'newspapers', 'whipped/sour cream'}): 0.0015371249081066632,
#  frozenset({'newspapers', 'tropical fruit'}): 0.001871282496825503,
#  frozenset({'newspapers', 'soda'}): 0.0023391031210318785,
#  frozenset({'newspapers', 'shopping bags'}): 0.001804450979081735,
#  frozenset({'newspapers', 'sausage'}): 0.001804450979081735,
#  frozenset({'newspapers', 'root vegetables'}): 0.0025395976742631824,
#  frozenset({'newspapers', 'rolls/buns'}): 0.003007418298469558,
#  frozenset({'newspapers', 'pip fruit'}): 0.0012697988371315912,
#  frozenset({'newspapers', 'pastry'}): 0.002004945532313039,
#  frozenset({'newspapers', 'other vegetables'}): 0.0036757334759072377,
#  frozenset({'grapes'}): 0.01443560783265388,
#  frozenset({'grapes', 'whole milk'}): 0.0019381140145692708,
#  frozenset({'grapes', 'soda'}): 0.001403461872619127,
#  frozenset({'grapes', 'sausage'}): 0.0010693042839002875,
#  frozenset({'grapes', 'root vegetables'}): 0.0010693042839002875,
#  frozenset({'grapes', 'rolls/buns'}): 0.0012029673193878234,
#  frozenset({'grapes', 'other vegetables'}): 0.001603956425850431,
#  frozenset({'fruit/vegetable juice'}): 0.03401724253157789,
#  frozenset({'fruit/vegetable juice', 'yogurt'}): 0.002205440085544343,
#  frozenset({'fruit/vegetable juice', 'whole milk'}): 0.004410880171088686,
#  frozenset({'fruit/vegetable juice', 'tropical fruit'}): 0.002138608567800575,
#  frozenset({'fruit/vegetable juice', 'soda'}): 0.002138608567800575,
#  frozenset({'fruit/vegetable juice', 'sausage'}): 0.001804450979081735,
#  frozenset({'fruit/vegetable juice', 'root vegetables'}): 0.001804450979081735,
#  frozenset({'fruit/vegetable juice', 'rolls/buns'}): 0.003742564993651006,
#  frozenset({'fruit/vegetable juice', 'pip fruit'}): 0.001403461872619127,
#  frozenset({'fruit/vegetable juice', 'pastry'}): 0.0014702933903628951,
#  frozenset({'fruit/vegetable juice',
#             'other vegetables'}): 0.0029405867807257902,
#  frozenset({'fruit/vegetable juice', 'margarine'}): 0.0010024727661565194,
#  frozenset({'frozen vegetables'}): 0.028002405934638777,
#  frozenset({'frozen vegetables', 'yogurt'}): 0.0020717770500568067,
#  frozenset({'frozen vegetables', 'whole milk'}): 0.003809396511394774,
#  frozenset({'frozen vegetables', 'tropical fruit'}): 0.0010693042839002875,
#  frozenset({'frozen vegetables', 'soda'}): 0.002004945532313039,
#  frozenset({'frozen vegetables', 'sausage'}): 0.0020717770500568067,
#  frozenset({'frozen vegetables', 'root vegetables'}): 0.002138608567800575,
#  frozenset({'frozen vegetables', 'rolls/buns'}): 0.0027400922274944863,
#  frozenset({'frozen vegetables', 'pip fruit'}): 0.0013366303548753592,
#  frozenset({'frozen vegetables', 'other vegetables'}): 0.003141081333957094,
#  frozenset({'frozen potato products'}): 0.0048118692775512934,
#  frozenset({'frozen meals'}): 0.016774710953685757,
#  frozenset({'frozen meals', 'yogurt'}): 0.0013366303548753592,
#  frozenset({'frozen meals', 'whole milk'}): 0.0019381140145692708,
#  frozenset({'frozen meals', 'soda'}): 0.0015371249081066632,
#  frozenset({'frozen meals', 'sausage'}): 0.0012697988371315912,
#  frozenset({'frozen meals', 'rolls/buns'}): 0.0014702933903628951,
#  frozenset({'frozen meals', 'other vegetables'}): 0.002138608567800575,
#  frozenset({'frozen fish'}): 0.006816814809864332,
#  frozenset({'frozen fish', 'whole milk'}): 0.0010693042839002875,
#  frozenset({'frozen dessert'}): 0.006148499632426653,
#  frozenset({'frankfurter'}): 0.037759807525228894,
#  frozenset({'frankfurter', 'yogurt'}): 0.0025395976742631824,
#  frozenset({'frankfurter', 'whole milk'}): 0.005279689901757669,
#  frozenset({'frankfurter', 'whipped/sour cream'}): 0.0014702933903628951,
#  frozenset({'beverages', 'other vegetables'}): 0.0017376194613379669,
#  frozenset({'beverages', 'bottled water'}): 0.0010693042839002875,
#  frozenset({'berries'}): 0.021787074784468355,
#  frozenset({'berries', 'yogurt'}): 0.001403461872619127,
#  frozenset({'berries', 'whole milk'}): 0.0022722716032881106,
#  frozenset({'berries', 'tropical fruit'}): 0.0012697988371315912,
#  frozenset({'berries', 'soda'}): 0.0014702933903628951,
#  frozenset({'berries', 'root vegetables'}): 0.0010693042839002875,
#  frozenset({'berries', 'rolls/buns'}): 0.001670787943594199,
#  frozenset({'berries', 'pip fruit'}): 0.0011361358016440553,
#  frozenset({'berries', 'pastry'}): 0.0010693042839002875,
#  frozenset({'berries', 'other vegetables'}): 0.0026732607097507185,
#  frozenset({'berries', 'bottled water'}): 0.0010693042839002875,
#  frozenset({'beef'}): 0.03395041101383412,
#  frozenset({'beef', 'yogurt'}): 0.002205440085544343,
#  frozenset({'beef', 'whole milk'}): 0.004678206242063757,
#  frozenset({'beef', 'whipped/sour cream'}): 0.001403461872619127,
#  frozenset({'beef', 'tropical fruit'}): 0.0011361358016440553,
#  frozenset({'beef', 'soda'}): 0.001804450979081735,
#  frozenset({'beef', 'shopping bags'}): 0.0012697988371315912,
#  frozenset({'beef', 'root vegetables'}): 0.001670787943594199,
#  frozenset({'beef', 'rolls/buns'}): 0.001603956425850431,
#  frozenset({'beef', 'pastry'}): 0.0012029673193878234,
#  frozenset({'beef', 'other vegetables'}): 0.002806923745238254,
#  frozenset({'beef', 'newspapers'}): 0.001670787943594199,
#  frozenset({'beef', 'margarine'}): 0.001403461872619127,
#  frozenset({'beef', 'fruit/vegetable juice'}): 0.0010693042839002875,
#  frozenset({'beef', 'frozen vegetables'}): 0.0012697988371315912,
#  frozenset({'beef', 'frankfurter'}): 0.0010024727661565194,
#  frozenset({'beef', 'domestic eggs'}): 0.0011361358016440553,
#  frozenset({'beef', 'curd'}): 0.0012697988371315912,
#  frozenset({'beef', 'citrus fruit'}): 0.001804450979081735,
#  frozenset({'beef', 'canned beer'}): 0.0010024727661565194,
#  frozenset({'beef', 'butter'}): 0.0011361358016440553,
#  frozenset({'beef', 'brown bread'}): 0.0015371249081066632,
#  frozenset({'beef', 'bottled water'}): 0.0013366303548753592,
#  frozenset({'beef', 'bottled beer'}): 0.0010693042839002875,
#  frozenset({'bathroom cleaner'}): 0.0011361358016440553,
#  frozenset({'baking powder'}): 0.008086613646995923,
#  frozenset({'artif. sweetener'}): 0.0019381140145692708,
#  frozenset({'abrasive cleaner'}): 0.0014702933903628951}

# %%
# definiujemy funkcje obliczajace support, confidence i lift
from itertools import chain

def support(supports, products: tuple[str]) -> float:
    key = frozenset(products)

    if key in supports:
        return supports[key]
    return 0

def confidence(supports, prior_products: tuple[str], following_products: tuple[str]) -> float:
    supp_sum = support(supports, tuple(chain(prior_products, following_products)))
    supp_prior = support(supports, prior_products)

    if supp_prior == 0:
        return 0
    return supp_sum / supp_prior

def lift(supports, prior_products: tuple[str], following_products: tuple[str]) -> float:
    supp_sum = support(supports, tuple(chain(prior_products, following_products)))
    supp_prior = support(supports, prior_products)
    supp_following = support(supports, following_products)

    if supp_following == 0 or supp_prior == 0:
        return 0

    return supp_sum / supp_prior / supp_following

# %%
print(support(supports, {'whole milk', 'rolls/buns'}))
print(confidence(supports, {'whole milk', 'rolls/buns'}, {'yogurt'}))
print(lift(supports, {'whole milk', 'rolls/buns'}, {'yogurt'}))
# Out:
# 0.013967787208447505
# 0.09569377990430622
# 1.1142926293448514

# %% [markdown]
# ## Część 3. - generowanie rekomendacji

# %%
# wyznaczamy liste potencjalnych rekomendacji
# rekomendowane artykuly powinny miec lift > 1 i jak najwyzszy confidence

def generate_basic_candidates(basket: tuple[str], products: list[str], supports) -> list[tuple[str, tuple[str], float, float]]:
    # return [(item, subbasket, confidence, lift)]
    products = tuple(product for product in products if product not in basket)
    recommendations = []
    for subbasket in powerset(basket):
        for item in products:
            conf = confidence(supports, subbasket, (item, ))
            lft = lift(supports, subbasket, (item, ))
            if  lft > 1:
                recommendations.append((item, subbasket, conf, lft))
    return sorted(recommendations, key=lambda x: x[2], reverse=True)

# %%
# zaproponuj drugi, bardziej zaawansowany algorytm, np.:
# - jesli produkt X wystepuje w liscie kandydatow kilkukrotnie, oblicz srednia lub iloczyn confidence
# - posortuj kandydatow po iloczynie configence i lift
from collections import defaultdict
from itertools import chain, combinations


def generate_advanced_candidates(basket: tuple[str], products: list[str], supports) -> list[tuple[str, tuple[str], float, float]]:
    # return [(item, subbasket, confidence, lift)]
    products = tuple(product for product in products if product not in basket)
    recommendations = defaultdict(list)

    for subbasket in powerset(basket):
        for item in products:
            conf = confidence(supports, subbasket, (item, ))
            lft = lift(supports, subbasket, (item, ))
            if lft > 1:
                recommendations[item].append((conf, lft, subbasket))

    aggregated_recommendations = []
    for item, values in recommendations.items():
        avg_confidence = sum(conf for conf, _, _, in values) / len(values)
        product_lift = 1
        best_subbasket = None

        for _, lft, subbasket in values:
            product_lift *= lft
            if best_subbasket is None or len(subbasket) > len(best_subbasket):
                best_subbasket = subbasket
        aggregated_recommendations.append((item, best_subbasket, avg_confidence, product_lift))

    return sorted(aggregated_recommendations, key=lambda x: x[2] * x[3], reverse=True)

# %%
from IPython.display import display, HTML

def format_recommendations(recommendations):
  """Formatting recommendations list to table format"""

  table = "<table><thead><tr><th>Produkt</th><th>Subbasket</th><th>Confidence</th><th>Lift</th></tr></thead><tbody>"
  for item, subbasket, confidence, lift in recommendations:
    table += f"<tr><td>{item}</td><td>{subbasket}</td><td>{confidence:.4f}</td><td>{lift:.4f}</td></tr>"
  table += "</tbody></table>"

  display(HTML(table))

# %%
print(baskets[1])
format_recommendations(generate_basic_candidates(baskets[1], products, supports))
# Out:
# {'yogurt', 'semi-finished bread', 'sausage', 'whole milk'}
# <table><thead><tr><th>Produkt</th><th>Subbasket</th><th>Confidence</th><th>Lift</th></tr></thead><tbody><tr><td>rolls/buns</td><td>('sausage', 'whole milk')</td><td>0.1269</td><td>1.1533</td></tr><tr><td>rolls/buns</td><td>('yogurt', 'whole milk')</td><td>0.1198</td><td>1.0887</td></tr><tr><td>soda</td><td>('sausage', 'whole milk')</td><td>0.1194</td><td>1.2296</td></tr><tr><td>soda</td><td>('sausage',)</td><td>0.0986</td><td>1.0150</td></tr><tr><td>bottled beer</td><td>('sausage',)</td><td>0.0554</td><td>1.2220</td></tr><tr><td>citrus fruit</td><td>('yogurt',)</td><td>0.0537</td><td>1.0106</td></tr><tr><td>pastry</td><td>('sausage',)</td><td>0.0532</td><td>1.0276</td></tr><tr><td>curd</td><td>('sausage',)</td><td>0.0487</td><td>1.4466</td></tr><tr><td>frozen vegetables</td><td>('sausage',)</td><td>0.0343</td><td>1.2260</td></tr><tr><td>beverages</td><td>('sausage',)</td><td>0.0255</td><td>1.5368</td></tr><tr><td>dessert</td><td>('sausage',)</td><td>0.0244</td><td>1.0327</td></tr><tr><td>frozen meals</td><td>('sausage',)</td><td>0.0210</td><td>1.2543</td></tr><tr><td>salty snack</td><td>('sausage',)</td><td>0.0188</td><td>1.0025</td></tr><tr><td>sliced cheese</td><td>('sausage',)</td><td>0.0188</td><td>1.3414</td></tr><tr><td>grapes</td><td>('sausage',)</td><td>0.0177</td><td>1.2274</td></tr><tr><td>misc. beverages</td><td>('sausage',)</td><td>0.0177</td><td>1.1234</td></tr><tr><td>ham</td><td>('whole milk',)</td><td>0.0174</td><td>1.0141</td></tr><tr><td>chewing gum</td><td>('yogurt',)</td><td>0.0163</td><td>1.3585</td></tr><tr><td>hard cheese</td><td>('yogurt',)</td><td>0.0148</td><td>1.0056</td></tr><tr><td>soft cheese</td><td>('yogurt',)</td><td>0.0148</td><td>1.4750</td></tr><tr><td>specialty bar</td><td>('yogurt',)</td><td>0.0140</td><td>1.0029</td></tr><tr><td>herbs</td><td>('yogurt',)</td><td>0.0132</td><td>1.2529</td></tr><tr><td>detergent</td><td>('yogurt',)</td><td>0.0125</td><td>1.4443</td></tr><tr><td>detergent</td><td>('whole milk',)</td><td>0.0089</td><td>1.0308</td></tr></tbody></table>

# %%
format_recommendations(generate_advanced_candidates(baskets[1], products, supports))
# Out:
# <table><thead><tr><th>Produkt</th><th>Subbasket</th><th>Confidence</th><th>Lift</th></tr></thead><tbody><tr><td>rolls/buns</td><td>('yogurt', 'whole milk')</td><td>0.1233</td><td>1.2556</td></tr><tr><td>soda</td><td>('sausage', 'whole milk')</td><td>0.1090</td><td>1.2480</td></tr><tr><td>curd</td><td>('sausage',)</td><td>0.0487</td><td>1.4466</td></tr><tr><td>bottled beer</td><td>('sausage',)</td><td>0.0554</td><td>1.2220</td></tr><tr><td>pastry</td><td>('sausage',)</td><td>0.0532</td><td>1.0276</td></tr><tr><td>citrus fruit</td><td>('yogurt',)</td><td>0.0537</td><td>1.0106</td></tr><tr><td>frozen vegetables</td><td>('sausage',)</td><td>0.0343</td><td>1.2260</td></tr><tr><td>beverages</td><td>('sausage',)</td><td>0.0255</td><td>1.5368</td></tr><tr><td>frozen meals</td><td>('sausage',)</td><td>0.0210</td><td>1.2543</td></tr><tr><td>sliced cheese</td><td>('sausage',)</td><td>0.0188</td><td>1.3414</td></tr><tr><td>dessert</td><td>('sausage',)</td><td>0.0244</td><td>1.0327</td></tr><tr><td>chewing gum</td><td>('yogurt',)</td><td>0.0163</td><td>1.3585</td></tr><tr><td>soft cheese</td><td>('yogurt',)</td><td>0.0148</td><td>1.4750</td></tr><tr><td>grapes</td><td>('sausage',)</td><td>0.0177</td><td>1.2274</td></tr><tr><td>misc. beverages</td><td>('sausage',)</td><td>0.0177</td><td>1.1234</td></tr><tr><td>salty snack</td><td>('sausage',)</td><td>0.0188</td><td>1.0025</td></tr><tr><td>ham</td><td>('whole milk',)</td><td>0.0174</td><td>1.0141</td></tr><tr><td>herbs</td><td>('yogurt',)</td><td>0.0132</td><td>1.2529</td></tr><tr><td>detergent</td><td>('yogurt',)</td><td>0.0107</td><td>1.4888</td></tr><tr><td>hard cheese</td><td>('yogurt',)</td><td>0.0148</td><td>1.0056</td></tr><tr><td>specialty bar</td><td>('yogurt',)</td><td>0.0140</td><td>1.0029</td></tr></tbody></table>

# %%
print(baskets[33])
format_recommendations(generate_basic_candidates(baskets[33], products, supports))
# Out:
# {'photo/film', 'yogurt', 'tropical fruit', 'soda', 'domestic eggs', 'root vegetables', 'white wine'}
# <table><thead><tr><th>Produkt</th><th>Subbasket</th><th>Confidence</th><th>Lift</th></tr></thead><tbody><tr><td>sausage</td><td>('yogurt',)</td><td>0.0669</td><td>1.1090</td></tr><tr><td>sausage</td><td>('soda',)</td><td>0.0613</td><td>1.0150</td></tr><tr><td>citrus fruit</td><td>('yogurt',)</td><td>0.0537</td><td>1.0106</td></tr><tr><td>shopping bags</td><td>('root vegetables',)</td><td>0.0480</td><td>1.0094</td></tr><tr><td>newspapers</td><td>('domestic eggs',)</td><td>0.0414</td><td>1.0654</td></tr><tr><td>coffee</td><td>('domestic eggs',)</td><td>0.0378</td><td>1.1970</td></tr><tr><td>frankfurter</td><td>('domestic eggs',)</td><td>0.0378</td><td>1.0021</td></tr><tr><td>frozen vegetables</td><td>('root vegetables',)</td><td>0.0307</td><td>1.0978</td></tr><tr><td>white bread</td><td>('domestic eggs',)</td><td>0.0270</td><td>1.1265</td></tr><tr><td>uht-milk</td><td>('tropical fruit',)</td><td>0.0227</td><td>1.0606</td></tr><tr><td>specialty chocolate</td><td>('tropical fruit',)</td><td>0.0197</td><td>1.2348</td></tr><tr><td>beverages</td><td>('soda',)</td><td>0.0193</td><td>1.1627</td></tr><tr><td>meat</td><td>('root vegetables',)</td><td>0.0192</td><td>1.1408</td></tr><tr><td>waffles</td><td>('root vegetables',)</td><td>0.0192</td><td>1.0378</td></tr><tr><td>oil</td><td>('soda',)</td><td>0.0186</td><td>1.2468</td></tr><tr><td>sliced cheese</td><td>('root vegetables',)</td><td>0.0173</td><td>1.2320</td></tr><tr><td>chewing gum</td><td>('yogurt',)</td><td>0.0163</td><td>1.3585</td></tr><tr><td>flour</td><td>('tropical fruit',)</td><td>0.0158</td><td>1.6171</td></tr><tr><td>grapes</td><td>('root vegetables',)</td><td>0.0154</td><td>1.0647</td></tr><tr><td>processed cheese</td><td>('root vegetables',)</td><td>0.0154</td><td>1.5130</td></tr><tr><td>cat food</td><td>('tropical fruit',)</td><td>0.0148</td><td>1.2505</td></tr><tr><td>hard cheese</td><td>('yogurt',)</td><td>0.0148</td><td>1.0056</td></tr><tr><td>soft cheese</td><td>('yogurt',)</td><td>0.0148</td><td>1.4750</td></tr><tr><td>grapes</td><td>('soda',)</td><td>0.0145</td><td>1.0012</td></tr><tr><td>hygiene articles</td><td>('root vegetables',)</td><td>0.0144</td><td>1.0517</td></tr><tr><td>specialty bar</td><td>('yogurt',)</td><td>0.0140</td><td>1.0029</td></tr><tr><td>herbs</td><td>('yogurt',)</td><td>0.0132</td><td>1.2529</td></tr><tr><td>detergent</td><td>('yogurt',)</td><td>0.0125</td><td>1.4443</td></tr></tbody></table>

# %%
format_recommendations(generate_advanced_candidates(baskets[33], products, supports))
# Out:
# <table><thead><tr><th>Produkt</th><th>Subbasket</th><th>Confidence</th><th>Lift</th></tr></thead><tbody><tr><td>sausage</td><td>('yogurt',)</td><td>0.0641</td><td>1.1256</td></tr><tr><td>citrus fruit</td><td>('yogurt',)</td><td>0.0537</td><td>1.0106</td></tr><tr><td>shopping bags</td><td>('root vegetables',)</td><td>0.0480</td><td>1.0094</td></tr><tr><td>coffee</td><td>('domestic eggs',)</td><td>0.0378</td><td>1.1970</td></tr><tr><td>newspapers</td><td>('domestic eggs',)</td><td>0.0414</td><td>1.0654</td></tr><tr><td>frankfurter</td><td>('domestic eggs',)</td><td>0.0378</td><td>1.0021</td></tr><tr><td>frozen vegetables</td><td>('root vegetables',)</td><td>0.0307</td><td>1.0978</td></tr><tr><td>white bread</td><td>('domestic eggs',)</td><td>0.0270</td><td>1.1265</td></tr><tr><td>flour</td><td>('tropical fruit',)</td><td>0.0158</td><td>1.6171</td></tr><tr><td>specialty chocolate</td><td>('tropical fruit',)</td><td>0.0197</td><td>1.2348</td></tr><tr><td>uht-milk</td><td>('tropical fruit',)</td><td>0.0227</td><td>1.0606</td></tr><tr><td>processed cheese</td><td>('root vegetables',)</td><td>0.0154</td><td>1.5130</td></tr><tr><td>oil</td><td>('soda',)</td><td>0.0186</td><td>1.2468</td></tr><tr><td>beverages</td><td>('soda',)</td><td>0.0193</td><td>1.1627</td></tr><tr><td>chewing gum</td><td>('yogurt',)</td><td>0.0163</td><td>1.3585</td></tr><tr><td>meat</td><td>('root vegetables',)</td><td>0.0192</td><td>1.1408</td></tr><tr><td>soft cheese</td><td>('yogurt',)</td><td>0.0148</td><td>1.4750</td></tr><tr><td>sliced cheese</td><td>('root vegetables',)</td><td>0.0173</td><td>1.2320</td></tr><tr><td>waffles</td><td>('root vegetables',)</td><td>0.0192</td><td>1.0378</td></tr><tr><td>cat food</td><td>('tropical fruit',)</td><td>0.0148</td><td>1.2505</td></tr><tr><td>detergent</td><td>('yogurt',)</td><td>0.0125</td><td>1.4443</td></tr><tr><td>herbs</td><td>('yogurt',)</td><td>0.0132</td><td>1.2529</td></tr><tr><td>grapes</td><td>('soda',)</td><td>0.0149</td><td>1.0660</td></tr><tr><td>hygiene articles</td><td>('root vegetables',)</td><td>0.0144</td><td>1.0517</td></tr><tr><td>hard cheese</td><td>('yogurt',)</td><td>0.0148</td><td>1.0056</td></tr><tr><td>specialty bar</td><td>('yogurt',)</td><td>0.0140</td><td>1.0029</td></tr></tbody></table>
